# %%
# !unzip /content/Deep_Learning_for_sequential_Analysis.zip
# Out:
# Archive:  /content/Deep_Learning_for_sequential_Analysis.zip
#    creating: Deep_Learning_for_sequential_Analysis/
#   inflating: Deep_Learning_for_sequential_Analysis/App.ipynb
#   inflating: Deep_Learning_for_sequential_Analysis/config.py
#    creating: Deep_Learning_for_sequential_Analysis/data/
#   inflating: Deep_Learning_for_sequential_Analysis/data/IMDB Dataset.csv
#   inflating: Deep_Learning_for_sequential_Analysis/main.py
#    creating: Deep_Learning_for_sequential_Analysis/models/
#   inflating: Deep_Learning_for_sequential_Analysis/models/cnn_model.py
#   inflating: Deep_Learning_for_sequential_Analysis/models/rnn_models.py
#   inflating: Deep_Learning_for_sequential_Analysis/models/transformer_model.py
#    creating: Deep_Learning_for_sequential_Analysis/models/__pycache__/
#   inflating: Deep_Learning_for_sequential_Analysis/models/__pycache__/cnn_model.cpython-312.pyc
#   inflating: Deep_Learning_for_sequential_Analysis/models/__pycache__/peft_model.cpython-312.pyc
# ...

# %% [markdown]
# # Install requirements

# %%
# !pip install -r /content/Deep_Learning_for_sequential_Analysis/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 54.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 52.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 35.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 26.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# # Set up Wansb

# %%
import wandb

wandb_key = "e90baa7b9ec072327076d381a30a2c61432c92c9"
wandb.login(key=wandb_key)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: anndischeh (anndischeh-univ-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# # 1. Run for CNN model

# %%
# %run /content/Deep_Learning_for_sequential_Analysis/main.py --model_type cnn --mode all --text "I fell asleep halfway through."
# Out:
# Seed set to 42
# Using device: cuda
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250515_191236-kgim6u1y</code>
# Syncing run <strong><a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/kgim6u1y' target="_blank">cnn_all_20250515_191236</a></strong> to <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis</a>
# ...

# %% [markdown]
# # 2. Run for DCNN model

# %%
# %run /content/Deep_Learning_for_sequential_Analysis/main.py --model_type dcnn --mode all --text "I fell asleep halfway through."
# Out:
# Seed set to 42
# Using device: cuda
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250515_191952-4jre712r</code>
# Syncing run <strong><a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/4jre712r' target="_blank">dcnn_all_20250515_191952</a></strong> to <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis</a>
#  View run at <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/4jre712r' target="_blank">https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/4jre712r</a>
# ...

# %% [markdown]
# # 3. Run for RNN model

# %%
# %run /content/Deep_Learning_for_sequential_Analysis/main.py  --model_type rnn --mode all --text "I fell asleep halfway through."
# Out:
# Seed set to 42
# Using device: cuda
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250515_193843-stiroogk</code>
# Syncing run <strong><a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/stiroogk' target="_blank">rnn_all_20250515_193843</a></strong> to <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis</a>
#  View run at <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/stiroogk' target="_blank">https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/stiroogk</a>
# ...

# %% [markdown]
# # 4. Run for LSTM model

# %%
# %run /content/Deep_Learning_for_sequential_Analysis/main.py  --model_type lstm --mode all --text "I fell asleep halfway through."
# Out:
# Seed set to 42
# Using device: cuda
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250515_193102-zkogrvlv</code>
# Syncing run <strong><a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/zkogrvlv' target="_blank">lstm_all_20250515_193102</a></strong> to <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis</a>
#  View run at <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/zkogrvlv' target="_blank">https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/zkogrvlv</a>
# ...

# %% [markdown]
# # 4. Run for GRU model

# %%
# %run /content/Deep_Learning_for_sequential_Analysis/main.py  --model_type gru --mode all --text "I fell asleep halfway through."
# Out:
# Seed set to 42
# Using device: cuda
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250515_194453-olqr99cv</code>
# Syncing run <strong><a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/olqr99cv' target="_blank">gru_all_20250515_194453</a></strong> to <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis</a>
#  View run at <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/olqr99cv' target="_blank">https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/olqr99cv</a>
# ...

# %% [markdown]
# # Run for DistilBert moddel

# %%
# %run /content/Deep_Learning_for_sequential_Analysis/main.py  --model_type distilbert --mode all --text "I fell asleep halfway through."
# Out:
# Seed set to 42
# Using device: cuda
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250515_195134-wb9ic6m6</code>
# Syncing run <strong><a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/wb9ic6m6' target="_blank">distilbert_all_20250515_195134</a></strong> to <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis' target="_blank">https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis</a>
#  View run at <a href='https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/wb9ic6m6' target="_blank">https://wandb.ai/anndischeh-univ-/Deep%20Learning%20for%20Sequential%20Analysis/runs/wb9ic6m6</a>
# ...
